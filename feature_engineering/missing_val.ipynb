# %%
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# #Applying imputation techniques for handling the missing values

# %% [markdown]
# #mean imputation technique

# %%
sns.histplot(df["age"],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df["age"].fillna(df["age"].mean(),inplace=True)

# %%
df["age"].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.histplot(df["age"],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>
